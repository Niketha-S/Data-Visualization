# %% [markdown]
#  ### Pyplot is a collection of functions that make matplotlib work like MATLAB. Each pyplot function makes some change to a figure

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
rcParams['figure.figsize'] = (12,6)
sns.set()

# %%
df = pd.read_csv(r'C:\Users\Vineeth_Infor\Desktop\Data Science\Cars_sales.csv')

# %%
df.head()
# Out:
#    Manufacturer  Model Sales in thousands  4-year resale value Vehicle type  \
# 0           NaN  Acura            Integra               16.919        16.36
# 1           NaN  Acura                 TL               39.384       19.875
# 2           NaN  Acura                 CL               14.114       18.225
# 3           NaN  Acura                 RL                8.588       29.725
# 4           NaN   Audi                 A4               20.397       22.255
#
#   Price in thousands Engine size  Horsepower  Wheelbase  Width  Length  \
# 0          Passenger        21.5         1.8        140  101.2    67.3
# 1          Passenger        28.4         3.2        225  108.1    70.3
# 2          Passenger           .         3.2        225  106.9    70.6
# 3          Passenger          42         3.5        210  114.6    71.4
# 4          Passenger       23.99         1.8        150  102.6    68.2
#
#    Curb weight Fuel capacity  Fuel efficiency  Latest Launch Unnamed: 15
# ...

# %%
# Data to plot
labels = 'Acura', 'Audi', 'BMW', 'Benz'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
df = pd.read_csv(r'C:\Users\Vineeth_Infor\Desktop\Data Science\day_wise.csv')
df.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
city = ('chennai', 'Thirchy', 'Tanjore')
y_pos = np.arange(len(city))
Active = [510,606,879]

plt.bar(y_pos, Active, align='center', alpha=0.5)
plt.xticks(y_pos, city)
plt.ylabel('Active cases')
plt.title('COVID 19')

plt.show()

# %%
Active = [510,606,879]
Recovery =[28,30,26]
plt.plot(Active,Recovery)
plt.title('Active cases Vs Recovered cases')
plt.xlabel('Active')
plt.ylabel('Recovered')
plt.show()
