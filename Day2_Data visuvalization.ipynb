# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from numpy.random import randn

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.187774 -0.851464 -1.544643  1.803099
# 1 -0.670551 -1.930837 -1.071978  1.899914
# 2 -0.210238  0.088559  0.118998 -0.336925
# 3  0.139112  1.315137 -0.689017  0.636588
# 4 -0.679624 -0.899618  1.192397 -1.198954
# 5 -0.403774 -0.217052 -0.770201  0.293630
# 6  0.099231  0.746226  0.722229  2.004697
# 7 -2.249633 -1.015943  0.577320 -0.342864
# 8  0.228243 -0.197189  0.063241 -0.702127
# 9 -1.679868  0.539870  0.209701  0.503184

# %%
df.head(5)
# Out:
#           a         b         c         d
# 0 -0.187774 -0.851464 -1.544643  1.803099
# 1 -0.670551 -1.930837 -1.071978  1.899914
# 2 -0.210238  0.088559  0.118998 -0.336925
# 3  0.139112  1.315137 -0.689017  0.636588
# 4 -0.679624 -0.899618  1.192397 -1.198954

# %%
df.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.561487  -0.242231  -0.119195   0.456024
# std     0.814141   0.964915   0.869214   1.140481
# min    -2.249633  -1.930837  -1.544643  -1.198954
# 25%    -0.677356  -0.887580  -0.749905  -0.341379
# 50%    -0.307006  -0.207121   0.091119   0.398407
# 75%     0.027480   0.427042   0.485416   1.511472
# max     0.228243   1.315137   1.192397   2.004697

# %%
df.plot.bar()
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Assingment 2")
plt.legend()
plt.plot()
# Out:
# []
